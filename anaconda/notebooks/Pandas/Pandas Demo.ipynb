# %%
import pandas as pd

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#current directory
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /opt/notebooks/Pandas

# %%
import pandas as pd

df = pd.read_csv('dirtydata.csv')

print(df.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# 17        60  '2020/12/17'    100       120     300.0
# 18        45  '2020/12/18'     90       112       NaN
# 19        60  '2020/12/19'    103       123     323.0
# 20        45  '2020/12/20'     97       125     243.0
# 21        60  '2020/12/21'    108       131     364.2
# 22        45           NaN    100       119     282.0
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# 25        60  '2020/12/25'    102       126     334.5
# 26        60      20201226    100       120     250.0
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
#https://www.datacamp.com/community/tutorials/pandas
#http://insideairbnb.com/get-the-data.html; new york summary information (uncompressed csv file)
import pandas as pd

airbnb = pd.read_csv("listings.csv")

display(airbnb)
# Out:
#              id                                               name   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...      4869
# 2          5121                                    BlissArtsSpace!      7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden      7378
# 4          5178                   Large Furnished Room Near B'way　      8967
# ...         ...                                                ...       ...
# 36719  51447515         Gorgeous 2 Bedroom - in Prime Midtown East  51589519
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...   2971741
# 36721  51450816                                    The Hunter IIII  61391963
# 36722  51451029                        Rockaway Beach Surf Getaway  10123226
# 36723  51451368                       Nyc apt in the middle in nyc  17770287
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0            Jennifer           Manhattan             Midtown  40.753560
# 1         LisaRoxanne            Brooklyn  Bedford-Stuyvesant  40.684940
# 2               Garon            Brooklyn  Bedford-Stuyvesant  40.685350
# 3             Rebecca            Brooklyn         Sunset Park  40.662650
# 4            Shunichi           Manhattan             Midtown  40.764570
# ...               ...                 ...                 ...        ...
# 36719             Asi           Manhattan             Midtown  40.755787
# 36720      Dina Marie           Manhattan     Upper West Side  40.787029
# 36721  Stay With Vibe           Manhattan     Upper East Side  40.768950
# 36722           Chase              Queens             Arverne  40.599257
# 36723            Nina           Manhattan         Murray Hill  40.748655
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0     -73.985590  Entire home/apt    150              30                 48
# 1     -73.957650  Entire home/apt     75               1                408
# 2     -73.955120     Private room     60              30                 50
# 3     -73.994540  Entire home/apt    275               5                  1
# 4     -73.983170     Private room     61               2                485
# ...          ...              ...    ...             ...                ...
# 36719 -73.965126  Entire home/apt    255              31                  0
# 36720 -73.969239  Entire home/apt    306               5                  0
# 36721 -73.960455  Entire home/apt     63              30                  0
# 36722 -73.797953     Private room     75               1                  0
# 36723 -73.981209  Entire home/apt    115              30                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2019-11-04               0.34                               3
# 1      2021-06-29               5.09                               1
# 2      2016-06-05               0.55                               1
# 3      2014-01-02               0.01                               1
# 4      2021-07-18               3.63                               1
# ...           ...                ...                             ...
# 36719         NaN                NaN                               6
# 36720         NaN                NaN                               1
# 36721         NaN                NaN                              96
# 36722         NaN                NaN                               1
# 36723         NaN                NaN                              11
#
#        availability_365
# 0                   341
# 1                   212
# 2                   365
# 3                   184
# 4                   255
# ...                 ...
# 36719               364
# 36720                16
# 36721               334
# 36722                87
# 36723               364
#
# [36724 rows x 16 columns]

# %%
hosts = airbnb[['host_id', 'host_name']]
hosts.head()
# Out:
#    host_id    host_name
# 0     2845     Jennifer
# 1     4869  LisaRoxanne
# 2     7356        Garon
# 3     7378      Rebecca
# 4     8967     Shunichi

# %%
hosts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36724 entries, 0 to 36723
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   host_id    36724 non-null  int64
#  1   host_name  36701 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 573.9+ KB

# %%
airbnb.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
airbnb['last_review'] = pd.to_datetime(airbnb['last_review'])
airbnb.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# dtype: object

# %%
# extract the year from a datetime series
airbnb['year'] = airbnb['last_review'].dt.year
airbnb['year'].head()
# Out:
# 0    2019.0
# 1    2021.0
# 2    2016.0
# 3    2014.0
# 4    2021.0
# Name: year, dtype: float64

# %%
display(airbnb)
# Out:
#              id                                               name   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...      4869
# 2          5121                                    BlissArtsSpace!      7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden      7378
# 4          5178                   Large Furnished Room Near B'way　      8967
# ...         ...                                                ...       ...
# 36719  51447515         Gorgeous 2 Bedroom - in Prime Midtown East  51589519
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...   2971741
# 36721  51450816                                    The Hunter IIII  61391963
# 36722  51451029                        Rockaway Beach Surf Getaway  10123226
# 36723  51451368                       Nyc apt in the middle in nyc  17770287
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0            Jennifer           Manhattan             Midtown  40.753560
# 1         LisaRoxanne            Brooklyn  Bedford-Stuyvesant  40.684940
# 2               Garon            Brooklyn  Bedford-Stuyvesant  40.685350
# 3             Rebecca            Brooklyn         Sunset Park  40.662650
# 4            Shunichi           Manhattan             Midtown  40.764570
# ...               ...                 ...                 ...        ...
# 36719             Asi           Manhattan             Midtown  40.755787
# 36720      Dina Marie           Manhattan     Upper West Side  40.787029
# 36721  Stay With Vibe           Manhattan     Upper East Side  40.768950
# 36722           Chase              Queens             Arverne  40.599257
# 36723            Nina           Manhattan         Murray Hill  40.748655
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0     -73.985590  Entire home/apt    150              30                 48
# 1     -73.957650  Entire home/apt     75               1                408
# 2     -73.955120     Private room     60              30                 50
# 3     -73.994540  Entire home/apt    275               5                  1
# 4     -73.983170     Private room     61               2                485
# ...          ...              ...    ...             ...                ...
# 36719 -73.965126  Entire home/apt    255              31                  0
# 36720 -73.969239  Entire home/apt    306               5                  0
# 36721 -73.960455  Entire home/apt     63              30                  0
# 36722 -73.797953     Private room     75               1                  0
# 36723 -73.981209  Entire home/apt    115              30                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2019-11-04               0.34                               3
# 1      2021-06-29               5.09                               1
# 2      2016-06-05               0.55                               1
# 3      2014-01-02               0.01                               1
# 4      2021-07-18               3.63                               1
# ...           ...                ...                             ...
# 36719         NaT                NaN                               6
# 36720         NaT                NaN                               1
# 36721         NaT                NaN                              96
# 36722         NaT                NaN                               1
# 36723         NaT                NaN                              11
#
#        availability_365    year
# 0                   341  2019.0
# 1                   212  2021.0
# 2                   365  2016.0
# 3                   184  2014.0
# 4                   255  2021.0
# ...                 ...     ...
# 36719               364     NaN
# 36720                16     NaN
# 36721               334     NaN
# 36722                87     NaN
# 36723               364     NaN
#
# [36724 rows x 17 columns]

# %%
# Strip leading and trailing spaces from a string series
airbnb['name'] = airbnb['name'].str.strip()
airbnb['name'].head()
# Out:
# 0                                Skylit Midtown Castle
# 1    Whole flr w/private bdrm, bath & kitchen(pls r...
# 2                                      BlissArtsSpace!
# 3             Spacious Brooklyn Duplex, Patio + Garden
# 4                      Large Furnished Room Near B'way
# Name: name, dtype: object

# %%
# lowercase all strings in a series
airbnb['name_lower'] = airbnb['name'].str.lower()
airbnb['name_lower'].head()
# Out:
# 0                                skylit midtown castle
# 1    whole flr w/private bdrm, bath & kitchen(pls r...
# 2                                      blissartsspace!
# 3             spacious brooklyn duplex, patio + garden
# 4                      large furnished room near b'way
# Name: name_lower, dtype: object

# %%
# calculate using two columns
airbnb['min_revenue'] = airbnb['minimum_nights'] * airbnb['price']
airbnb[['minimum_nights', 'price', 'min_revenue']].head()
# Out:
#    minimum_nights  price  min_revenue
# 0              30    150         4500
# 1               1     75           75
# 2              30     60         1800
# 3               5    275         1375
# 4               2     61          122

# %%
airbnb['price'].mean()
# Out:
# 160.10905674763097

# %%
airbnb['price'].median()
# Out:
# 108.0

# %%
# get the mean grouped by type of room
airbnb[['room_type', 'price']].groupby('room_type', as_index=False).mean()
# Out:
#          room_type       price
# 0  Entire home/apt  213.324779
# 1       Hotel room  293.262548
# 2     Private room   96.617690
# 3      Shared room  107.978297

# %%
# get the median grouped by type of room
airbnb[['room_type', 'price']].groupby('room_type', as_index=False).median()
# Out:
#          room_type  price
# 0  Entire home/apt    151
# 1       Hotel room    214
# 2     Private room     67
# 3      Shared room     50

# %%
# get the median grouped by type of room and year
airbnb[['room_type', 'year', 'price']].groupby(['room_type', 'year'], as_index=False).median()
# Out:
#           room_type    year  price
# 0   Entire home/apt  2010.0  228.0
# 1   Entire home/apt  2011.0  165.0
# 2   Entire home/apt  2012.0  150.0
# 3   Entire home/apt  2013.0  150.0
# 4   Entire home/apt  2014.0  170.0
# 5   Entire home/apt  2015.0  150.0
# 6   Entire home/apt  2016.0  150.0
# 7   Entire home/apt  2017.0  149.0
# 8   Entire home/apt  2018.0  150.0
# 9   Entire home/apt  2019.0  150.0
# 10  Entire home/apt  2020.0  148.0
# 11  Entire home/apt  2021.0  150.0
# 12       Hotel room  2016.0  349.0
# 13       Hotel room  2017.0  248.0
# 14       Hotel room  2018.0  125.0
# 15       Hotel room  2019.0  291.0
# 16       Hotel room  2020.0  211.5
# 17       Hotel room  2021.0  165.0
# 18     Private room  2011.0  349.0
# 19     Private room  2012.0   90.0
# 20     Private room  2013.0  100.0
# 21     Private room  2014.0   80.0
# 22     Private room  2015.0   75.0
# 23     Private room  2016.0   65.0
# 24     Private room  2017.0   65.0
# 25     Private room  2018.0   65.0
# 26     Private room  2019.0   69.0
# 27     Private room  2020.0   63.0
# 28     Private room  2021.0   68.0
# 29      Shared room  2013.0   50.0
# 30      Shared room  2014.0   82.0
# 31      Shared room  2015.0   61.5
# 32      Shared room  2016.0   95.0
# 33      Shared room  2017.0   51.0
# 34      Shared room  2018.0   57.0
# 35      Shared room  2019.0   55.0
# 36      Shared room  2020.0   45.0
# 37      Shared room  2021.0   40.0

# %%
# get all rows with price < 1000
airbnb_under_1000 = airbnb[airbnb['price'] < 1000]
airbnb_under_1000.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                    Large Furnished Room Near B'way     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75356  -73.98559
# 1  LisaRoxanne            Brooklyn  Bedford-Stuyvesant  40.68494  -73.95765
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 3      Rebecca            Brooklyn         Sunset Park  40.66265  -73.99454
# 4     Shunichi           Manhattan             Midtown  40.76457  -73.98317
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    150              30                 48  2019-11-04
# 1  Entire home/apt     75               1                408  2021-06-29
# 2     Private room     60              30                 50  2016-06-05
# 3  Entire home/apt    275               5                  1  2014-01-02
# 4     Private room     61               2                485  2021-07-18
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.34                               3               341
# 1               5.09                               1               212
# 2               0.55                               1               365
# 3               0.01                               1               184
# 4               3.63                               1               255
#
#      year                                         name_lower  min_revenue
# 0  2019.0                              skylit midtown castle         4500
# 1  2021.0  whole flr w/private bdrm, bath & kitchen(pls r...           75
# 2  2016.0                                    blissartsspace!         1800
# 3  2014.0           spacious brooklyn duplex, patio + garden         1375
# 4  2021.0                    large furnished room near b'way          122

# %%
airbnb_under_1000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36396 entries, 0 to 36723
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36396 non-null  int64
#  1   name                            36383 non-null  object
#  2   host_id                         36396 non-null  int64
#  3   host_name                       36373 non-null  object
#  4   neighbourhood_group             36396 non-null  object
#  5   neighbourhood                   36396 non-null  object
#  6   latitude                        36396 non-null  float64
#  7   longitude                       36396 non-null  float64
#  8   room_type                       36396 non-null  object
#  9   price                           36396 non-null  int64
#  10  minimum_nights                  36396 non-null  int64
#  11  number_of_reviews               36396 non-null  int64
#  12  last_review                     27145 non-null  datetime64[ns]
#  13  reviews_per_month               27145 non-null  float64
#  14  calculated_host_listings_count  36396 non-null  int64
#  15  availability_365                36396 non-null  int64
#  16  year                            27145 non-null  float64
#  17  name_lower                      36383 non-null  object
#  18  min_revenue                     36396 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(6)
# memory usage: 5.6+ MB

# %%
# filtering multiple conditions
# get all rows with price < 1000 and year equal to 2020
airbnb_2019_under_1000 = airbnb[(airbnb['price'] < 1000) & (airbnb['year'] == 2020)]
airbnb_2019_under_1000.head()
# Out:
#        id                                               name  host_id  \
# 7    6848                   Only 2 stops to Manhattan studio    15991
# 17   9704                Spacious 1 bedroom in luxe building    32045
# 21  12192                                ENJOY Downtown NYC!    46978
# 29  14314                     Greenpoint Place...Has It All!    56246
# 31  15341  Bright 1bd Nolita Apt, Doorman, Elevator, Secu...    60049
#
#         host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 7   Allen & Irina            Brooklyn  Williamsburg  40.70935  -73.95342
# 17           Teri           Manhattan        Harlem  40.81317  -73.95465
# 21         Edward           Manhattan  East Village  40.72296  -73.98383
# 29         Jeanne            Brooklyn    Greenpoint  40.73535  -73.95584
# 31            Ted           Manhattan        Nolita  40.72297  -73.99684
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 7   Entire home/apt     89              30                181  2020-03-09
# 17     Private room     55              30                 98  2020-03-14
# 21     Private room     40               2                265  2020-11-14
# 29  Entire home/apt     99              30                179  2020-03-14
# 31  Entire home/apt    191              30                 26  2020-10-14
#
#     reviews_per_month  calculated_host_listings_count  availability_365  \
# 7                1.27                               1               263
# 17               1.44                               1               216
# 21               2.04                               2                30
# 29               2.11                               1               215
# 31               0.72                               1                65
#
#       year                                         name_lower  min_revenue
# 7   2020.0                   only 2 stops to manhattan studio         2670
# 17  2020.0                spacious 1 bedroom in luxe building         1650
# 21  2020.0                                enjoy downtown nyc!           80
# 29  2020.0                     greenpoint place...has it all!         2970
# 31  2020.0  bright 1bd nolita apt, doorman, elevator, secu...         5730

# %%
# distribution of prices under $1000
ax = airbnb_under_1000['price'].plot.hist(bins=40)
